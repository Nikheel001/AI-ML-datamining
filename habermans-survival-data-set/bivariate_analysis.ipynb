# %%
# bivariate analysis

from pandas import read_csv
from matplotlib import pyplot
from seaborn import pairplot

cs =read_csv('haberman.csv')
pairplot(cs,hue='Surv_status', height=4)
pyplot.show()

'''

'''
# Out:
# '\n'
